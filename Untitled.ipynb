# %%
cp -r ~/.cache/huggingface/* /workspace/AAIPL/hf_models/.

# %%
import os
os.environ["HF_HUB_CACHE"] = "/root/.cache/huggingface"

# %%
# !python -m agents-Copy1.question_agent \
    --output_file "outputs/questions.json" \
    --num_questions 2 \
    --verbose
# Out:
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# `torch_dtype` is deprecated! Use `dtype` instead!
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# ...

# %%
# !python -m agents-Copy1.answer_agent \
    --input_file "outputs/filtered_questions.json" \
    --output_file "outputs/answers.json" \
    --verbose
# Out:
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# `torch_dtype` is deprecated! Use `dtype` instead!
# Could not cache non-existence of file. Will ignore error and continue. Error: [Errno 30] Read-only file system: '/root/.cache/huggingface/models--Qwen--Qwen3-4B/.no_exist'
# ...

# %%
# Out:
# README.ipynb    agents/        git.sh      qgen.yaml             utils/
# Untitled.ipynb  agents-Copy1/  hf_models/  tutorial.ipynb
# agen.yaml       assets/        outputs/    tutorial_config.yaml

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 zip -v
#
# NameError: name 'v' is not defined
